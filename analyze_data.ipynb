# %%
# importing libraries for analysis and visualisation
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import pandas as pd

# Read the CSV file into a DataFrame
nf = pd.read_csv("Netflix_Engagement_Report_2023_Jan-Jun_cleaned.csv")

# Display the first few rows of the DataFrame
print(nf.head())
# Out:
#                                  Title Available Globally Release Date  \
# 0            The Night Agent: Season 1                Yes    3/23/2023
# 1            Ginny & Georgia: Season 2                Yes     1/5/2023
# 2   The Glory: Season 1 // 더 글로리: 시즌 1                Yes   12/30/2022
# 3                  Wednesday: Season 1                Yes   11/23/2022
# 4  Queen Charlotte: A Bridgerton Story                Yes     5/4/2023
#
#    Hours Viewed
# 0     812100000
# 1     665100000
# 2     622800000
# 3     507700000
# 4     503000000

# %%
# Create the years and durations lists
years = [i for i in range(2011, 2021)]
durations = [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]

# Create a dictionary with the two lists
movie_dict = {'years': years,
              'durations' : durations
             }

# Print the dictionary
movie_dict
# Out:
# {'years': [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
#  'durations': [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]}

# %%
# Import pandas under its usual alias
import pandas as pd

# Create a DataFrame from the dictionary
durations_df = pd.DataFrame(movie_dict)

# Print the DataFrame
durations_df
# Out:
#    years  durations
# 0   2011        103
# 1   2012        101
# 2   2013         99
# 3   2014        100
# 4   2015        100
# 5   2016         95
# 6   2017         95
# 7   2018         96
# 8   2019         93
# 9   2020         90

# %%
# Import matplotlib.pyplot under its usual alias and create a figure
import matplotlib.pyplot as plt
fig = plt.figure()

# Draw a line plot of release_years and durations
plt.plot(durations_df["years"], durations_df['durations'])

# Create a title
plt.title('Netflix Movie Durations 2011-2020')

# Show the plot
plt.plot()
# Out:
# []

# %%
import os
import pandas as pd

# Get the current working directory
current_directory = os.getcwd()
print("Current Directory:", current_directory)

# List the files in the current directory to verify file existence
files_in_directory = os.listdir(current_directory)
print("Files in Directory:", files_in_directory)

# Read in the CSV as a DataFrame
netflix_df = pd.read_csv('Netflix_Engagement_Report_2023_Jan-Jun_cleaned.csv')

# Print the first five rows of the DataFrame
print(netflix_df.head(15))
# Out:
# Current Directory: c:\Users\Akmal Rabbani\Downloads\Big D
# Files in Directory: ['analyze_data.ipynb', 'Netflix_Engagement_Report_2023_Jan-Jun_cleaned.csv', 'netflix_titles.csv']
#                                         Title Available Globally Release Date  \
# 0                   The Night Agent: Season 1                Yes    3/23/2023
# 1                   Ginny & Georgia: Season 2                Yes     1/5/2023
# 2          The Glory: Season 1 // 더 글로리: 시즌 1                Yes   12/30/2022
# 3                         Wednesday: Season 1                Yes   11/23/2022
# 4         Queen Charlotte: A Bridgerton Story                Yes     5/4/2023
# 5                               You: Season 4                Yes     2/9/2023
# 6                  La Reina del Sur: Season 3                 No   12/30/2022
# 7                       Outer Banks: Season 3                Yes    2/23/2023
# 8                   Ginny & Georgia: Season 1                Yes    2/24/2021
# ...

# %%
import pandas as pd

# Read in the CSV as a DataFrame
netflix_df = pd.read_csv('Netflix_Engagement_Report_2023_Jan-Jun_cleaned.csv')

# Check column names
print(netflix_df.columns)

# Display structure of the DataFrame
print(netflix_df.head())
# Out:
# Index(['Title', 'Available Globally', 'Release Date', 'Hours Viewed'], dtype='object')
#                                  Title Available Globally Release Date  \
# 0            The Night Agent: Season 1                Yes    3/23/2023
# 1            Ginny & Georgia: Season 2                Yes     1/5/2023
# 2   The Glory: Season 1 // 더 글로리: 시즌 1                Yes   12/30/2022
# 3                  Wednesday: Season 1                Yes   11/23/2022
# 4  Queen Charlotte: A Bridgerton Story                Yes     5/4/2023
#
#    Hours Viewed
# 0     812100000
# 1     665100000
# 2     622800000
# 3     507700000
# 4     503000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

# Load the Netflix dataset
netflix_df = pd.read_csv("netflix_titles.csv")

# Filter the dataset to only include movies
netflix_movies = netflix_df[netflix_df['type'] == 'Movie']

# Select a subset of columns to use in the scatter plot
netflix_movies_col_subset = netflix_movies[['release_year', 'duration']]

# Create a figure and increase the figure size
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of duration versus year
plt.scatter(netflix_movies_col_subset['release_year'], netflix_movies_col_subset['duration'])

# Create a title
plt.title('Movie Duration by Year of Release')

# Show the plot
plt.show()

# %%
import pandas as pd

# Create a DataFrame from the dictionary
movie_dict = {
    'years': [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
    'durations': [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]
}

durations_df = pd.DataFrame(movie_dict)

# Convert 'durations' column to numeric values
durations_df['durations'] = pd.to_numeric(durations_df['durations'], errors='coerce')

# Filter for durations shorter than 60 minutes
short_movies = durations_df[durations_df['durations'] < 100]

# Print the first 20 rows of short_movies
print(short_movies.head(20))
# Out:
#    years  durations
# 2   2013         99
# 5   2016         95
# 6   2017         95
# 7   2018         96
# 8   2019         93
# 9   2020         90

# %%
import pandas as pd

# Define an empty list
colors = []

# Check if durations_df is a DataFrame
if isinstance(durations_df, pd.DataFrame):
    # Check if 'genre' column exists
    if 'genre' in durations_df.columns:
        # Iterate over rows of durations_df
        for idx, row in durations_df.iterrows():
            if row['genre'] == 'Children':
                colors.append('red')
            elif row['genre'] == 'Documentaries':
                colors.append('blue')
            elif row['genre'] == 'Stand-Up':
                colors.append('green')
            else:
                colors.append('black')
    else:
        print('Column does not exist.')
else:
    print('durations_df is not a DataFrame.')
# Out:
# Column does not exist.

# %%
import matplotlib.pyplot as plt

# Create the years and durations lists
years = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
durations = [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]

# Set the figure style and initialize a new figure
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12, 8))

# Create a scatter plot of duration versus release_year
plt.scatter(durations_df['years'], durations_df['durations'])

# Create a title and axis labels
plt.title('Movie duration by year of release')
plt.xlabel('Release year')
plt.ylabel('Duration(min)')

# Show the plot
plt.show()

# %%
import pandas as pd

# Contoh DataFrame durations_df
movie_dict = {
    'years': [2011, 2012, 2013, 2014, 2015],
    'durations': [103, 101, 99, 100, 95]
}

durations_df = pd.DataFrame(movie_dict)

# Menghitung statistik deskriptif dari kolom 'durations'
statistics = durations_df['durations'].describe()
print(statistics)
# Out:
# count      5.000000
# mean      99.600000
# std        2.966479
# min       95.000000
# 25%       99.000000
# 50%      100.000000
# 75%      101.000000
# max      103.000000
# Name: durations, dtype: float64

# %%
# Membuat histogram untuk distribusi durasi film
plt.hist(durations_df['durations'], bins=10, edgecolor='black')
plt.title('Distribution of Movie Durations')
plt.xlabel('Duration (min)')
plt.ylabel('Frequency')
plt.show()

# %%
# Contoh data genre film (dalam bentuk DataFrame)
genre_data = pd.DataFrame({
    'film_id': [1, 2, 3, 4, 5],
    'genre': ['Action', 'Comedy', 'Drama', 'Action', 'Comedy'],
    'duration': [120, 95, 110, 105, 100]
})

# Menampilkan rata-rata durasi film berdasarkan genre
average_duration_by_genre = genre_data.groupby('genre')['duration'].mean()
print(average_duration_by_genre)
# Out:
# genre
# Action    112.5
# Comedy     97.5
# Drama     110.0
# Name: duration, dtype: float64

# %%
# Membuat line plot untuk melihat tren durasi film dari tahun ke tahun
plt.plot(durations_df['years'], durations_df['durations'], marker='o')
plt.title('Trend of Movie Durations Over Years')
plt.xlabel('Release Year')
plt.ylabel('Duration (min)')
plt.grid(True)
plt.show()

# %%
# Create the years and durations lists
years = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
durations = [103, 101, 99, 100, 100, 95, 95, 96, 93, 90]

# Check if movies are getting shorter
are_movies_getting_shorter = durations[-1] < durations[0]

# Show the result
if are_movies_getting_shorter:
    print("Movies are getting shorter over the years.")
else:
    print("Movies are not getting shorter over the years.")
# Out:
# Movies are getting shorter over the years.
